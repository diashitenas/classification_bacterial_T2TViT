# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
# !pip uninstall torch torchvision torchaudio
# Out:
# ^C

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("smaranjitghose/corn-or-maize-leaf-disease-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\PC\.cache\kagglehub\datasets\smaranjitghose\corn-or-maize-leaf-disease-dataset\versions\1

# %%
# !pip install vit-pytorch
# Out:
# Collecting vit-pytorch
#   Downloading vit_pytorch-1.10.1-py3-none-any.whl.metadata (69 kB)
# Collecting einops>=0.7.0 (from vit-pytorch)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch>=1.10 in c:\users\pc\appdata\roaming\python\python311\site-packages (from vit-pytorch) (2.4.0)
# Requirement already satisfied: torchvision in c:\users\pc\appdata\roaming\python\python311\site-packages (from vit-pytorch) (0.19.0)
# Collecting filelock (from torch>=1.10->vit-pytorch)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch>=1.10->vit-pytorch) (4.12.2)
# Collecting sympy (from torch>=1.10->vit-pytorch)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.10->vit-pytorch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.10->vit-pytorch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch>=1.10->vit-pytorch) (2024.6.1)
# Collecting numpy<2 (from torchvision->vit-pytorch)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision->vit-pytorch)
#   Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.10->vit-pytorch)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.10->vit-pytorch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading vit_pytorch-1.10.1-py3-none-any.whl (140 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, numpy, networkx, MarkupSafe, filelock, einops, jinja2, vit-pytorch
# Successfully installed MarkupSafe-3.0.2 einops-0.8.1 filelock-3.17.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-1.26.4 pillow-11.1.0 sympy-1.13.3 vit-pytorch-1.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lpips 0.1.4 requires scipy>=1.0.1, which is not installed.
# visdom 0.2.4 requires jsonpatch, which is not installed.
# visdom 0.2.4 requires scipy, which is not installed.
# visdom 0.2.4 requires websocket-client, which is not installed.

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Define the transform
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# Define dataset directories
base_dir = r'D:\PENELITIAN\PENELITIAN - DIASH - HERBAL\Medicinal Leaf Dataset Split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# Load datasets from separate folders
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
val_dataset = datasets.ImageFolder(val_dir, transform=transform)
test_dataset = datasets.ImageFolder(test_dir, transform=transform)

# Create DataLoaders
trainloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
valloader = DataLoader(val_dataset, batch_size=4, shuffle=True, num_workers=4)
testloader = DataLoader(test_dataset, batch_size=4, shuffle=True, num_workers=4)

# Print dataset sizes
print(f"Train size: {len(train_dataset)} samples, {len(train_dataset.classes)} classes")
print(f"Validation size: {len(val_dataset)} samples")
print(f"Test size: {len(test_dataset)} samples")

# Print class names (should be the same for all splits)
print("\nClass names:", train_dataset.classes)
# Out:
# Train size: 1284 samples, 30 classes
# Validation size: 275 samples
# Test size: 276 samples
#
# Class names: ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']

# %%
import torch
print(torch.cuda.is_available())  # Harus mengembalikan True jika CUDA tersedia
# Out:
# True

# %%
# Zufar's code
import torch
from vit_pytorch import ViT

import torch
from vit_pytorch.deepvit import DeepViT

v = DeepViT(
    image_size = 256,
    patch_size = 32,
    num_classes = 30,
    dim = 1024,
    depth = 6,
    heads = 16,
    mlp_dim = 2048,
    dropout = 0.1,
    emb_dropout = 0.1
)

# %%
import numpy as np
import torchvision

import matplotlib.pyplot as plt

# Ambil batch pertama dari train_loader
data_iter = iter(trainloader)
images, labels = next(data_iter)

# Fungsi untuk menampilkan gambar
def imshow(img):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Tampilkan grid gambar
imshow(torchvision.utils.make_grid(images))

# Tampilkan label
classes = ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(len(labels))))
# Out:
# Amaranthus Viridis (Arive-Dantu) Amaranthus Viridis (Arive-Dantu) Moringa Oleifera (Drumstick) Mentha (Mint)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
v.to(device)
# Out:
# DeepViT(
#   (to_patch_embedding): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=32, p2=32)
#     (1): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(in_features=3072, out_features=1024, bias=True)
#     (3): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (transformer): Transformer(
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): Attention(
#           (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (to_qkv): Linear(in_features=1024, out_features=3072, bias=False)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (reattn_norm): Sequential(
#             (0): Rearrange('b h i j -> b i j h')
#             (1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#             (2): Rearrange('b i j h -> b h i j')
#           )
#           (to_out): Sequential(
#             (0): Linear(in_features=1024, out_features=1024, bias=True)
#             (1): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): FeedForward(
#           (net): Sequential(
#             (0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (1): Linear(in_features=1024, out_features=2048, bias=True)
#             (2): GELU(approximate='none')
#             (3): Dropout(p=0.1, inplace=False)
#             (4): Linear(in_features=2048, out_features=1024, bias=True)
#             (5): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (to_latent): Identity()
#   (mlp_head): Sequential(
#     (0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=1024, out_features=30, bias=True)
#   )
# )

# %% [markdown]
# Kode Zufar

# %% [markdown]
# Kode Zufar + GPT tambahin akurasi doang

# %%
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(v.parameters(), lr=0.001, momentum=0.9)

# Inisialisasi list untuk menyimpan akurasi dan loss
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
test_accuracy = 0  # Akurasi pengujian hanya dihitung sekali di akhir

num_epochs = 100
for epoch in range(num_epochs):  # loop over the dataset multiple times
    correct = 0
    total = 0
    running_loss = 0.0  # Untuk menghitung training loss per epoch
    
    # Loop untuk setiap batch dalam trainloader
    for i, data in tqdm(enumerate(trainloader, 0), desc=f'Epoch {epoch + 1}/{num_epochs}'):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = v(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Menghitung jumlah prediksi yang benar
        _, predicted = torch.max(outputs.data, 1)  # Ambil kelas dengan probabilitas tertinggi
        total += labels.size(0)  # Menambah jumlah data yang telah diproses
        correct += (predicted == labels).sum().item()  # Hitung prediksi yang benar

        # Menghitung training loss
        running_loss += loss.item()

    # Akurasi dan loss per epoch pada data pelatihan
    accuracy = 100 * correct / total  # Akurasi dalam persentase
    epoch_loss = running_loss / len(trainloader)  # Rata-rata loss per epoch
    train_accuracies.append(accuracy)
    train_losses.append(epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Accuracy: {accuracy:.2f}%, Training Loss: {epoch_loss:.4f}')

    # Evaluasi pada data validasi
    v.eval()  # Set v ke mode evaluasi
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0  # Untuk menghitung validation loss per epoch
    with torch.no_grad():  # Non-aktifkan perhitungan gradien
        for data in valloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = v(inputs)
            loss = criterion(outputs, labels)
            val_running_loss += loss.item()  # Menghitung validation loss
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_accuracy = 100 * val_correct / val_total
    val_epoch_loss = val_running_loss / len(valloader)  # Rata-rata validation loss per epoch
    val_accuracies.append(val_accuracy)
    val_losses.append(val_epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Validation Accuracy: {val_accuracy:.2f}%, Validation Loss: {val_epoch_loss:.4f}')

    v.train()  # Kembalikan v ke mode pelatihan

print('Finished Training')

# Evaluasi pada data uji setelah pelatihan selesai
v.eval()  # Set v ke mode evaluasi
test_correct = 0
test_total = 0
with torch.no_grad():  # Non-aktifkan perhitungan gradien
    for data in testloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = v(inputs)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total
print(f'Test Accuracy: {test_accuracy:.2f}%')

# Plot grafik perbandingan akurasi dan loss
plt.figure(figsize=(12, 5))

# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy', marker='o')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy', marker='o')
# plt.axhline(y=test_accuracy, color='r', linestyle='--', label=f'Test Accuracy: {test_accuracy:.2f}%')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss', marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100: 321it [00:06, 51.24it/s]
# Epoch [1/100], Training Accuracy: 9.42%, Training Loss: 3.7524
# Epoch [1/100], Validation Accuracy: 7.64%, Validation Loss: 4.7177
# Epoch 2/100: 321it [00:05, 57.15it/s]
# Epoch [2/100], Training Accuracy: 15.89%, Training Loss: 3.2870
# Epoch [2/100], Validation Accuracy: 15.64%, Validation Loss: 2.6661
# Epoch 3/100: 321it [00:05, 57.42it/s]
# Epoch [3/100], Training Accuracy: 19.94%, Training Loss: 2.9114
# Epoch [3/100], Validation Accuracy: 18.55%, Validation Loss: 3.2299
# Epoch 4/100: 321it [00:05, 56.41it/s]
# Epoch [4/100], Training Accuracy: 20.87%, Training Loss: 2.8822
# Epoch [4/100], Validation Accuracy: 24.73%, Validation Loss: 2.8199
# Epoch 5/100: 321it [00:05, 58.73it/s]
# Epoch [5/100], Training Accuracy: 25.86%, Training Loss: 2.6461
# Epoch [5/100], Validation Accuracy: 19.64%, Validation Loss: 2.8222
# Epoch 6/100: 321it [00:05, 57.44it/s]
# Epoch [6/100], Training Accuracy: 26.71%, Training Loss: 2.6180
# Epoch [6/100], Validation Accuracy: 27.64%, Validation Loss: 2.7938
# Epoch 7/100: 321it [00:05, 57.98it/s]
# Epoch [7/100], Training Accuracy: 31.70%, Training Loss: 2.3686
# Epoch [7/100], Validation Accuracy: 25.45%, Validation Loss: 2.3728
# Epoch 8/100: 321it [00:05, 56.83it/s]
# Epoch [8/100], Training Accuracy: 38.08%, Training Loss: 2.0451
# Epoch [8/100], Validation Accuracy: 33.82%, Validation Loss: 1.9431
# Epoch 9/100: 321it [00:05, 57.71it/s]
# Epoch [9/100], Training Accuracy: 46.26%, Training Loss: 1.7901
# Epoch [9/100], Validation Accuracy: 36.73%, Validation Loss: 2.2455
# Epoch 10/100: 321it [00:05, 56.91it/s]
# Epoch [10/100], Training Accuracy: 48.44%, Training Loss: 1.6809
# Epoch [10/100], Validation Accuracy: 45.09%, Validation Loss: 1.7114
# Epoch 11/100: 321it [00:05, 57.15it/s]
# Epoch [11/100], Training Accuracy: 59.66%, Training Loss: 1.2670
# Epoch [11/100], Validation Accuracy: 52.00%, Validation Loss: 1.6812
# Epoch 12/100: 321it [00:05, 56.98it/s]
# Epoch [12/100], Training Accuracy: 60.59%, Training Loss: 1.2180
# Epoch [12/100], Validation Accuracy: 53.09%, Validation Loss: 1.7113
# Epoch 13/100: 321it [00:05, 57.62it/s]
# Epoch [13/100], Training Accuracy: 64.72%, Training Loss: 1.0864
# Epoch [13/100], Validation Accuracy: 49.09%, Validation Loss: 1.6920
# Epoch 14/100: 321it [00:05, 57.29it/s]
# Epoch [14/100], Training Accuracy: 67.37%, Training Loss: 0.9962
# Epoch [14/100], Validation Accuracy: 56.36%, Validation Loss: 1.4122
# Epoch 15/100: 321it [00:05, 57.19it/s]
# Epoch [15/100], Training Accuracy: 69.08%, Training Loss: 0.8972
# Epoch [15/100], Validation Accuracy: 58.18%, Validation Loss: 1.3793
# Epoch 16/100: 321it [00:05, 57.98it/s]
# Epoch [16/100], Training Accuracy: 72.82%, Training Loss: 0.8290
# Epoch [16/100], Validation Accuracy: 55.64%, Validation Loss: 1.4571
# Epoch 17/100: 321it [00:05, 56.82it/s]
# Epoch [17/100], Training Accuracy: 72.43%, Training Loss: 0.8215
# Epoch [17/100], Validation Accuracy: 61.82%, Validation Loss: 1.2003
# Epoch 18/100: 321it [00:05, 57.46it/s]
# Epoch [18/100], Training Accuracy: 76.17%, Training Loss: 0.7375
# Epoch [18/100], Validation Accuracy: 62.18%, Validation Loss: 1.3429
# Epoch 19/100: 321it [00:05, 57.45it/s]
# Epoch [19/100], Training Accuracy: 77.49%, Training Loss: 0.6949
# Epoch [19/100], Validation Accuracy: 64.73%, Validation Loss: 1.2141
# Epoch 20/100: 321it [00:05, 55.90it/s]
# Epoch [20/100], Training Accuracy: 81.07%, Training Loss: 0.5688
# Epoch [20/100], Validation Accuracy: 69.82%, Validation Loss: 0.9957
# Epoch 21/100: 321it [00:05, 57.22it/s]
# Epoch [21/100], Training Accuracy: 79.75%, Training Loss: 0.6120
# Epoch [21/100], Validation Accuracy: 65.09%, Validation Loss: 1.2540
# Epoch 22/100: 321it [00:05, 56.29it/s]
# Epoch [22/100], Training Accuracy: 82.79%, Training Loss: 0.5424
# Epoch [22/100], Validation Accuracy: 62.18%, Validation Loss: 1.3350
# Epoch 23/100: 321it [00:05, 57.11it/s]
# Epoch [23/100], Training Accuracy: 82.55%, Training Loss: 0.5010
# Epoch [23/100], Validation Accuracy: 67.27%, Validation Loss: 1.2692
# Epoch 24/100: 321it [00:05, 57.07it/s]
# Epoch [24/100], Training Accuracy: 83.64%, Training Loss: 0.4968
# Epoch [24/100], Validation Accuracy: 59.64%, Validation Loss: 1.5533
# Epoch 25/100: 321it [00:05, 56.81it/s]
# Epoch [25/100], Training Accuracy: 84.97%, Training Loss: 0.4521
# Epoch [25/100], Validation Accuracy: 62.18%, Validation Loss: 1.3378
# Epoch 26/100: 321it [00:05, 58.00it/s]
# Epoch [26/100], Training Accuracy: 84.11%, Training Loss: 0.5100
# Epoch [26/100], Validation Accuracy: 66.18%, Validation Loss: 1.1502
# Epoch 27/100: 321it [00:05, 56.78it/s]
# Epoch [27/100], Training Accuracy: 86.21%, Training Loss: 0.3987
# Epoch [27/100], Validation Accuracy: 60.73%, Validation Loss: 1.5718
# Epoch 28/100: 321it [00:05, 57.59it/s]
# Epoch [28/100], Training Accuracy: 83.41%, Training Loss: 0.4684
# Epoch [28/100], Validation Accuracy: 63.64%, Validation Loss: 1.3196
# Epoch 29/100: 321it [00:05, 57.25it/s]
# Epoch [29/100], Training Accuracy: 86.45%, Training Loss: 0.3960
# Epoch [29/100], Validation Accuracy: 66.18%, Validation Loss: 1.2261
# Epoch 30/100: 321it [00:05, 57.54it/s]
# Epoch [30/100], Training Accuracy: 88.08%, Training Loss: 0.3484
# Epoch [30/100], Validation Accuracy: 71.27%, Validation Loss: 1.2382
# Epoch 31/100: 321it [00:05, 57.69it/s]
# Epoch [31/100], Training Accuracy: 88.32%, Training Loss: 0.3547
# Epoch [31/100], Validation Accuracy: 65.82%, Validation Loss: 1.6642
# Epoch 32/100: 321it [00:05, 56.80it/s]
# Epoch [32/100], Training Accuracy: 84.97%, Training Loss: 0.4385
# Epoch [32/100], Validation Accuracy: 70.55%, Validation Loss: 1.2273
# Epoch 33/100: 321it [00:05, 56.04it/s]
# Epoch [33/100], Training Accuracy: 87.07%, Training Loss: 0.3957
# Epoch [33/100], Validation Accuracy: 66.18%, Validation Loss: 1.3551
# Epoch 34/100: 321it [00:05, 57.52it/s]
# Epoch [34/100], Training Accuracy: 89.10%, Training Loss: 0.3216
# Epoch [34/100], Validation Accuracy: 61.45%, Validation Loss: 1.6473
# Epoch 35/100: 321it [00:05, 57.33it/s]
# Epoch [35/100], Training Accuracy: 90.26%, Training Loss: 0.3397
# Epoch [35/100], Validation Accuracy: 68.00%, Validation Loss: 1.3541
# Epoch 36/100: 321it [00:05, 57.45it/s]
# Epoch [36/100], Training Accuracy: 94.39%, Training Loss: 0.2033
# Epoch [36/100], Validation Accuracy: 70.91%, Validation Loss: 1.2710
# Epoch 37/100: 321it [00:05, 55.28it/s]
# Epoch [37/100], Training Accuracy: 92.60%, Training Loss: 0.2145
# Epoch [37/100], Validation Accuracy: 71.64%, Validation Loss: 1.1377
# Epoch 38/100: 321it [00:05, 55.26it/s]
# Epoch [38/100], Training Accuracy: 96.65%, Training Loss: 0.1267
# Epoch [38/100], Validation Accuracy: 61.82%, Validation Loss: 1.8285
# Epoch 39/100: 321it [00:05, 56.49it/s]
# Epoch [39/100], Training Accuracy: 93.30%, Training Loss: 0.1827
# Epoch [39/100], Validation Accuracy: 74.18%, Validation Loss: 1.1526
# Epoch 40/100: 321it [00:05, 56.59it/s]
# Epoch [40/100], Training Accuracy: 90.89%, Training Loss: 0.2741
# Epoch [40/100], Validation Accuracy: 64.00%, Validation Loss: 1.5505
# Epoch 41/100: 321it [00:05, 56.48it/s]
# Epoch [41/100], Training Accuracy: 90.58%, Training Loss: 0.2703
# Epoch [41/100], Validation Accuracy: 72.73%, Validation Loss: 1.3365
# Epoch 42/100: 321it [00:05, 56.93it/s]
# Epoch [42/100], Training Accuracy: 93.46%, Training Loss: 0.2088
# Epoch [42/100], Validation Accuracy: 64.36%, Validation Loss: 1.5502
# Epoch 43/100: 321it [00:05, 56.48it/s]
# Epoch [43/100], Training Accuracy: 92.06%, Training Loss: 0.2370
# Epoch [43/100], Validation Accuracy: 65.09%, Validation Loss: 1.3102
# Epoch 44/100: 321it [00:05, 58.30it/s]
# Epoch [44/100], Training Accuracy: 90.65%, Training Loss: 0.2615
# Epoch [44/100], Validation Accuracy: 64.36%, Validation Loss: 1.8239
# Epoch 45/100: 321it [00:05, 57.71it/s]
# Epoch [45/100], Training Accuracy: 91.74%, Training Loss: 0.2403
# Epoch [45/100], Validation Accuracy: 64.36%, Validation Loss: 1.6617
# Epoch 46/100: 321it [00:05, 57.78it/s]
# Epoch [46/100], Training Accuracy: 92.99%, Training Loss: 0.2150
# Epoch [46/100], Validation Accuracy: 66.18%, Validation Loss: 1.6498
# Epoch 47/100: 321it [00:05, 58.05it/s]
# Epoch [47/100], Training Accuracy: 97.27%, Training Loss: 0.0901
# Epoch [47/100], Validation Accuracy: 69.82%, Validation Loss: 1.3951
# Epoch 48/100: 321it [00:05, 56.07it/s]
# Epoch [48/100], Training Accuracy: 98.52%, Training Loss: 0.0430
# Epoch [48/100], Validation Accuracy: 72.36%, Validation Loss: 1.3746
# Epoch 49/100: 321it [00:05, 55.06it/s]
# Epoch [49/100], Training Accuracy: 99.38%, Training Loss: 0.0230
# Epoch [49/100], Validation Accuracy: 75.64%, Validation Loss: 1.4262
# Epoch 50/100: 321it [00:05, 57.09it/s]
# Epoch [50/100], Training Accuracy: 98.68%, Training Loss: 0.0481
# Epoch [50/100], Validation Accuracy: 74.91%, Validation Loss: 1.4060
# Epoch 51/100: 321it [00:05, 57.38it/s]
# Epoch [51/100], Training Accuracy: 96.96%, Training Loss: 0.0731
# Epoch [51/100], Validation Accuracy: 70.91%, Validation Loss: 1.5441
# Epoch 52/100: 321it [00:05, 57.47it/s]
# Epoch [52/100], Training Accuracy: 97.74%, Training Loss: 0.0717
# Epoch [52/100], Validation Accuracy: 73.45%, Validation Loss: 1.6312
# Epoch 53/100: 321it [00:05, 57.05it/s]
# Epoch [53/100], Training Accuracy: 93.93%, Training Loss: 0.1942
# Epoch [53/100], Validation Accuracy: 63.64%, Validation Loss: 1.6960
# Epoch 54/100: 321it [00:05, 58.43it/s]
# Epoch [54/100], Training Accuracy: 90.97%, Training Loss: 0.2578
# Epoch [54/100], Validation Accuracy: 72.73%, Validation Loss: 1.6990
# Epoch 55/100: 321it [00:05, 58.13it/s]
# Epoch [55/100], Training Accuracy: 93.77%, Training Loss: 0.2054
# Epoch [55/100], Validation Accuracy: 69.82%, Validation Loss: 1.3375
# Epoch 56/100: 321it [00:05, 58.13it/s]
# Epoch [56/100], Training Accuracy: 93.30%, Training Loss: 0.2043
# Epoch [56/100], Validation Accuracy: 66.91%, Validation Loss: 1.7686
# Epoch 57/100: 321it [00:05, 57.82it/s]
# Epoch [57/100], Training Accuracy: 91.43%, Training Loss: 0.2572
# Epoch [57/100], Validation Accuracy: 68.36%, Validation Loss: 1.5567
# Epoch 58/100: 321it [00:05, 56.98it/s]
# Epoch [58/100], Training Accuracy: 95.72%, Training Loss: 0.1240
# Epoch [58/100], Validation Accuracy: 72.00%, Validation Loss: 1.3371
# Epoch 59/100: 321it [00:05, 56.87it/s]
# Epoch [59/100], Training Accuracy: 97.51%, Training Loss: 0.0839
# Epoch [59/100], Validation Accuracy: 73.82%, Validation Loss: 1.2953
# Epoch 60/100: 321it [00:05, 57.53it/s]
# Epoch [60/100], Training Accuracy: 99.07%, Training Loss: 0.0293
# Epoch [60/100], Validation Accuracy: 74.91%, Validation Loss: 1.2162
# Epoch 61/100: 321it [00:05, 56.27it/s]
# Epoch [61/100], Training Accuracy: 99.07%, Training Loss: 0.0341
# Epoch [61/100], Validation Accuracy: 76.00%, Validation Loss: 1.2904
# Epoch 62/100: 321it [00:05, 57.85it/s]
# Epoch [62/100], Training Accuracy: 99.77%, Training Loss: 0.0154
# Epoch [62/100], Validation Accuracy: 74.91%, Validation Loss: 1.3166
# Epoch 63/100: 321it [00:05, 56.62it/s]
# Epoch [63/100], Training Accuracy: 99.77%, Training Loss: 0.0105
# Epoch [63/100], Validation Accuracy: 74.91%, Validation Loss: 1.3506
# Epoch 64/100: 321it [00:05, 56.27it/s]
# Epoch [64/100], Training Accuracy: 99.77%, Training Loss: 0.0075
# Epoch [64/100], Validation Accuracy: 77.09%, Validation Loss: 1.2782
# Epoch 65/100: 321it [00:05, 56.09it/s]
# Epoch [65/100], Training Accuracy: 100.00%, Training Loss: 0.0034
# Epoch [65/100], Validation Accuracy: 76.00%, Validation Loss: 1.2841
# Epoch 66/100: 321it [00:05, 56.77it/s]
# Epoch [66/100], Training Accuracy: 100.00%, Training Loss: 0.0030
# Epoch [66/100], Validation Accuracy: 76.73%, Validation Loss: 1.2499
# Epoch 67/100: 321it [00:05, 57.10it/s]
# Epoch [67/100], Training Accuracy: 100.00%, Training Loss: 0.0021
# Epoch [67/100], Validation Accuracy: 77.09%, Validation Loss: 1.2618
# Epoch 68/100: 321it [00:05, 58.29it/s]
# Epoch [68/100], Training Accuracy: 99.92%, Training Loss: 0.0033
# Epoch [68/100], Validation Accuracy: 76.36%, Validation Loss: 1.3042
# Epoch 69/100: 321it [00:05, 55.36it/s]
# Epoch [69/100], Training Accuracy: 100.00%, Training Loss: 0.0022
# Epoch [69/100], Validation Accuracy: 77.82%, Validation Loss: 1.2401
# Epoch 70/100: 321it [00:05, 56.36it/s]
# Epoch [70/100], Training Accuracy: 100.00%, Training Loss: 0.0019
# Epoch [70/100], Validation Accuracy: 78.18%, Validation Loss: 1.2205
# Epoch 71/100: 321it [00:05, 57.58it/s]
# Epoch [71/100], Training Accuracy: 100.00%, Training Loss: 0.0018
# Epoch [71/100], Validation Accuracy: 78.55%, Validation Loss: 1.2515
# Epoch 72/100: 321it [00:05, 58.16it/s]
# Epoch [72/100], Training Accuracy: 100.00%, Training Loss: 0.0019
# Epoch [72/100], Validation Accuracy: 77.09%, Validation Loss: 1.2698
# Epoch 73/100: 321it [00:05, 57.20it/s]
# Epoch [73/100], Training Accuracy: 100.00%, Training Loss: 0.0018
# Epoch [73/100], Validation Accuracy: 76.36%, Validation Loss: 1.2904
# Epoch 74/100: 321it [00:05, 57.89it/s]
# Epoch [74/100], Training Accuracy: 100.00%, Training Loss: 0.0015
# Epoch [74/100], Validation Accuracy: 76.36%, Validation Loss: 1.2766
# Epoch 75/100: 321it [00:05, 55.83it/s]
# Epoch [75/100], Training Accuracy: 100.00%, Training Loss: 0.0015
# Epoch [75/100], Validation Accuracy: 76.73%, Validation Loss: 1.2833
# Epoch 76/100: 321it [00:05, 56.98it/s]
# Epoch [76/100], Training Accuracy: 100.00%, Training Loss: 0.0012
# Epoch [76/100], Validation Accuracy: 76.73%, Validation Loss: 1.2757
# Epoch 77/100: 321it [00:05, 56.11it/s]
# Epoch [77/100], Training Accuracy: 100.00%, Training Loss: 0.0012
# Epoch [77/100], Validation Accuracy: 76.36%, Validation Loss: 1.2836
# Epoch 78/100: 321it [00:05, 55.87it/s]
# Epoch [78/100], Training Accuracy: 100.00%, Training Loss: 0.0011
# Epoch [78/100], Validation Accuracy: 77.09%, Validation Loss: 1.2815
# Epoch 79/100: 321it [00:05, 55.92it/s]
# Epoch [79/100], Training Accuracy: 100.00%, Training Loss: 0.0012
# Epoch [79/100], Validation Accuracy: 76.73%, Validation Loss: 1.2942
# Epoch 80/100: 321it [00:05, 57.13it/s]
# Epoch [80/100], Training Accuracy: 100.00%, Training Loss: 0.0010
# Epoch [80/100], Validation Accuracy: 76.73%, Validation Loss: 1.2909
# Epoch 81/100: 321it [00:05, 56.91it/s]
# Epoch [81/100], Training Accuracy: 100.00%, Training Loss: 0.0011
# Epoch [81/100], Validation Accuracy: 77.82%, Validation Loss: 1.2639
# Epoch 82/100: 321it [00:05, 55.86it/s]
# Epoch [82/100], Training Accuracy: 100.00%, Training Loss: 0.0011
# Epoch [82/100], Validation Accuracy: 77.82%, Validation Loss: 1.2923
# Epoch 83/100: 321it [00:05, 57.50it/s]
# Epoch [83/100], Training Accuracy: 100.00%, Training Loss: 0.0010
# Epoch [83/100], Validation Accuracy: 77.09%, Validation Loss: 1.2735
# Epoch 84/100: 321it [00:05, 57.77it/s]
# Epoch [84/100], Training Accuracy: 100.00%, Training Loss: 0.0009
# Epoch [84/100], Validation Accuracy: 77.09%, Validation Loss: 1.2906
# Epoch 85/100: 321it [00:05, 58.37it/s]
# Epoch [85/100], Training Accuracy: 100.00%, Training Loss: 0.0008
# Epoch [85/100], Validation Accuracy: 76.73%, Validation Loss: 1.3174
# Epoch 86/100: 321it [00:05, 57.91it/s]
# Epoch [86/100], Training Accuracy: 100.00%, Training Loss: 0.0009
# Epoch [86/100], Validation Accuracy: 76.73%, Validation Loss: 1.2962
# Epoch 87/100: 321it [00:05, 56.52it/s]
# Epoch [87/100], Training Accuracy: 100.00%, Training Loss: 0.0008
# Epoch [87/100], Validation Accuracy: 76.36%, Validation Loss: 1.3054
# Epoch 88/100: 321it [00:05, 55.50it/s]
# Epoch [88/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [88/100], Validation Accuracy: 76.36%, Validation Loss: 1.3046
# Epoch 89/100: 321it [00:05, 56.93it/s]
# Epoch [89/100], Training Accuracy: 100.00%, Training Loss: 0.0008
# Epoch [89/100], Validation Accuracy: 76.73%, Validation Loss: 1.3235
# Epoch 90/100: 321it [00:05, 57.53it/s]
# Epoch [90/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [90/100], Validation Accuracy: 76.36%, Validation Loss: 1.3122
# Epoch 91/100: 321it [00:05, 58.03it/s]
# Epoch [91/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [91/100], Validation Accuracy: 76.73%, Validation Loss: 1.3203
# Epoch 92/100: 321it [00:05, 55.42it/s]
# Epoch [92/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [92/100], Validation Accuracy: 76.73%, Validation Loss: 1.3262
# Epoch 93/100: 321it [00:05, 56.65it/s]
# Epoch [93/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [93/100], Validation Accuracy: 76.36%, Validation Loss: 1.3166
# Epoch 94/100: 321it [00:05, 55.55it/s]
# Epoch [94/100], Training Accuracy: 100.00%, Training Loss: 0.0005
# Epoch [94/100], Validation Accuracy: 76.36%, Validation Loss: 1.3178
# Epoch 95/100: 321it [00:05, 56.91it/s]
# Epoch [95/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [95/100], Validation Accuracy: 76.73%, Validation Loss: 1.3199
# Epoch 96/100: 321it [00:05, 57.45it/s]
# Epoch [96/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [96/100], Validation Accuracy: 76.73%, Validation Loss: 1.3279
# Epoch 97/100: 321it [00:05, 57.87it/s]
# Epoch [97/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [97/100], Validation Accuracy: 77.45%, Validation Loss: 1.3159
# Epoch 98/100: 321it [00:05, 57.17it/s]
# Epoch [98/100], Training Accuracy: 100.00%, Training Loss: 0.0007
# Epoch [98/100], Validation Accuracy: 76.73%, Validation Loss: 1.3258
# Epoch 99/100: 321it [00:05, 56.66it/s]
# Epoch [99/100], Training Accuracy: 100.00%, Training Loss: 0.0006
# Epoch [99/100], Validation Accuracy: 77.09%, Validation Loss: 1.3327
# Epoch 100/100: 321it [00:05, 56.04it/s]
# Epoch [100/100], Training Accuracy: 100.00%, Training Loss: 0.0006
# Epoch [100/100], Validation Accuracy: 77.45%, Validation Loss: 1.3331
# Finished Training
# Test Accuracy: 80.07%

# %%
import pandas as pd

# Create a DataFrame with the training and validation results
results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs + 1)),
    'Training Accuracy': train_accuracies,
    'Validation Accuracy': val_accuracies,
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})

# Save the DataFrame to a CSV file
results_csv_path = 'training_results_DeepViT.csv'
results_df.to_csv(results_csv_path, index=False)
print(f"Training results saved to {results_csv_path}")
# Out:
# Training results saved to training_results_DeepViT.csv

# %%
PATH = './model_DeepViT.pth'
torch.save(v.state_dict(), PATH)
print(f"Model saved to {PATH}")
# Out:
# Model saved to ./model_DeepViT.pth

# %%
import torch
import csv
from collections import OrderedDict

# Prepare to count predictions for each class
classes = ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 
           'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 
           'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 
           'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 
           'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 
           'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 
           'Mangifera Indica (Mango)', 'Mentha (Mint)', 
           'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 
           'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 
           'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 
           'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 
           'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 
           'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 
           'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 
           'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']

correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# No gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = v(images.to(device))  # Ganti 'v' dengan 'model' jika perlu
        _, predictions = torch.max(outputs, 1)
        
        # Collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            class_name = classes[label]
            total_pred[class_name] += 1
            if label == prediction:
                correct_pred[class_name] += 1

# Calculate accuracy and prepare data for CSV
results = []
for classname in classes:
    accuracy = 100 * float(correct_pred[classname]) / total_pred[classname] if total_pred[classname] != 0 else 0
    results.append({
        'Class': classname,
        'Correct_Predictions': correct_pred[classname],
        'Total_Predictions': total_pred[classname],
        'Accuracy (%)': round(accuracy, 2)
    })

# Save to CSV
csv_filename = 'conf_matrix_ViT.csv'
with open(csv_filename, mode='w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Class', 'Correct_Predictions', 'Total_Predictions', 'Accuracy (%)']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for row in results:
        writer.writerow(row)

print(f"\nConfusion matrix results saved to {csv_filename}")

# Print accuracy for each class
print("\nClass-wise Accuracy:")
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname] if total_pred[classname] != 0 else 0
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Confusion matrix results saved to conf_matrix_ViT.csv
#
# Class-wise Accuracy:
# Accuracy for class: Alpinia Galanga (Rasna) is 66.7 %
# Accuracy for class: Amaranthus Viridis (Arive-Dantu) is 83.3 %
# Accuracy for class: Artocarpus Heterophyllus (Jackfruit) is 88.9 %
# Accuracy for class: Azadirachta Indica (Neem) is 85.7 %
# Accuracy for class: Basella Alba (Basale) is 90.0 %
# Accuracy for class: Brassica Juncea (Indian Mustard) is 100.0 %
# Accuracy for class: Carissa Carandas (Karanda) is 92.3 %
# Accuracy for class: Citrus Limon (Lemon) is 100.0 %
# Accuracy for class: Ficus Auriculata (Roxburgh fig) is 57.1 %
# Accuracy for class: Ficus Religiosa (Peepal Tree) is 92.3 %
# Accuracy for class: Hibiscus Rosa-sinensis is 53.8 %
# Accuracy for class: Jasminum (Jasmine) is 66.7 %
# Accuracy for class: Mangifera Indica (Mango) is 57.1 %
# Accuracy for class: Mentha (Mint) is 91.7 %
# Accuracy for class: Moringa Oleifera (Drumstick) is 100.0 %
# Accuracy for class: Muntingia Calabura (Jamaica Cherry-Gasagase) is 75.0 %
# Accuracy for class: Murraya Koenigii (Curry) is 60.0 %
# Accuracy for class: Nerium Oleander (Oleander) is 90.9 %
# Accuracy for class: Nyctanthes Arbor-tristis (Parijata) is 100.0 %
# Accuracy for class: Ocimum Tenuiflorum (Tulsi) is 33.3 %
# Accuracy for class: Piper Betle (Betel) is 69.2 %
# Accuracy for class: Plectranthus Amboinicus (Mexican Mint) is 100.0 %
# Accuracy for class: Pongamia Pinnata (Indian Beech) is 75.0 %
# Accuracy for class: Psidium Guajava (Guava) is 100.0 %
# Accuracy for class: Punica Granatum (Pomegranate) is 77.8 %
# Accuracy for class: Santalum Album (Sandalwood) is 100.0 %
# Accuracy for class: Syzygium Cumini (Jamun) is 33.3 %
# Accuracy for class: Syzygium Jambos (Rose Apple) is 100.0 %
# Accuracy for class: Tabernaemontana Divaricata (Crape Jasmine) is 87.5 %
# Accuracy for class: Trigonella Foenum-graecum (Fenugreek) is 57.1 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Mengumpulkan semua label sebenarnya dan prediksi
all_labels = []
all_predictions = []

with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = v(images.to(device))
        _, predictions = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predictions.cpu().numpy())

# Membuat confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# Menampilkan confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
