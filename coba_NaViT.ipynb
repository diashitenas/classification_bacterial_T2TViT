# %%
# !pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
# !pip uninstall torch torchvision torchaudio
# Out:
# ^C

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\.conda\envs\vit_diash\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("smaranjitghose/corn-or-maize-leaf-disease-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\PC\.cache\kagglehub\datasets\smaranjitghose\corn-or-maize-leaf-disease-dataset\versions\1

# %%
# !pip install vit-pytorch
# Out:
# Collecting vit-pytorch
#   Downloading vit_pytorch-1.10.1-py3-none-any.whl.metadata (69 kB)
# Collecting einops>=0.7.0 (from vit-pytorch)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch>=1.10 in c:\users\pc\appdata\roaming\python\python311\site-packages (from vit-pytorch) (2.4.0)
# Requirement already satisfied: torchvision in c:\users\pc\appdata\roaming\python\python311\site-packages (from vit-pytorch) (0.19.0)
# Collecting filelock (from torch>=1.10->vit-pytorch)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch>=1.10->vit-pytorch) (4.12.2)
# Collecting sympy (from torch>=1.10->vit-pytorch)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.10->vit-pytorch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.10->vit-pytorch)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec in c:\users\pc\appdata\roaming\python\python311\site-packages (from torch>=1.10->vit-pytorch) (2024.6.1)
# Collecting numpy<2 (from torchvision->vit-pytorch)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision->vit-pytorch)
#   Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.10->vit-pytorch)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.10->vit-pytorch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading vit_pytorch-1.10.1-py3-none-any.whl (140 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached pillow-11.1.0-cp311-cp311-win_amd64.whl (2.6 MB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, pillow, numpy, networkx, MarkupSafe, filelock, einops, jinja2, vit-pytorch
# Successfully installed MarkupSafe-3.0.2 einops-0.8.1 filelock-3.17.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 numpy-1.26.4 pillow-11.1.0 sympy-1.13.3 vit-pytorch-1.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lpips 0.1.4 requires scipy>=1.0.1, which is not installed.
# visdom 0.2.4 requires jsonpatch, which is not installed.
# visdom 0.2.4 requires scipy, which is not installed.
# visdom 0.2.4 requires websocket-client, which is not installed.

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Define the transform
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor()
])

# Define dataset directories
base_dir = r'D:\PENELITIAN\PENELITIAN - DIASH - HERBAL\Medicinal Leaf Dataset Split'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# Load datasets from separate folders
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
val_dataset = datasets.ImageFolder(val_dir, transform=transform)
test_dataset = datasets.ImageFolder(test_dir, transform=transform)

# Create DataLoaders
trainloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=4)
valloader = DataLoader(val_dataset, batch_size=4, shuffle=True, num_workers=4)
testloader = DataLoader(test_dataset, batch_size=4, shuffle=True, num_workers=4)

# Print dataset sizes
print(f"Train size: {len(train_dataset)} samples, {len(train_dataset.classes)} classes")
print(f"Validation size: {len(val_dataset)} samples")
print(f"Test size: {len(test_dataset)} samples")

# Print class names (should be the same for all splits)
print("\nClass names:", train_dataset.classes)
# Out:
# Train size: 1284 samples, 30 classes
# Validation size: 275 samples
# Test size: 276 samples
#
# Class names: ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']

# %%
import torch
print(torch.cuda.is_available())  # Harus mengembalikan True jika CUDA tersedia
# Out:
# True

# %%
# Zufar's code
import torch
from vit_pytorch.na_vit import NaViT

v = NaViT(
    image_size = 256,
    patch_size = 32,
    num_classes = 30,
    dim = 1024,
    depth = 6,
    heads = 16,
    mlp_dim = 2048,
    dropout = 0.1,
    emb_dropout = 0.1,
    token_dropout_prob = 0.1  # token dropout of 10% (keep 90% of tokens)
)

# %%
import numpy as np
import torchvision

import matplotlib.pyplot as plt

# Ambil batch pertama dari train_loader
data_iter = iter(trainloader)
images, labels = next(data_iter)

# Fungsi untuk menampilkan gambar
def imshow(img):
    img = img / 2 + 0.5  # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Tampilkan grid gambar
imshow(torchvision.utils.make_grid(images))

# Tampilkan label
classes = ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(len(labels))))
# Out:
# Carissa Carandas (Karanda) Artocarpus Heterophyllus (Jackfruit) Punica Granatum (Pomegranate) Punica Granatum (Pomegranate)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
v.to(device)
# Out:
# NaViT(
#   (to_patch_embedding): Sequential(
#     (0): LayerNorm()
#     (1): Linear(in_features=3072, out_features=1024, bias=True)
#     (2): LayerNorm()
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (transformer): Transformer(
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): Attention(
#           (norm): LayerNorm()
#           (q_norm): RMSNorm()
#           (k_norm): RMSNorm()
#           (attend): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (to_q): Linear(in_features=1024, out_features=1024, bias=False)
#           (to_kv): Linear(in_features=1024, out_features=2048, bias=False)
#           (to_out): Sequential(
#             (0): Linear(in_features=1024, out_features=1024, bias=False)
#             (1): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): Sequential(
#           (0): LayerNorm()
#           (1): Linear(in_features=1024, out_features=2048, bias=True)
#           (2): GELU(approximate='none')
#           (3): Dropout(p=0.1, inplace=False)
#           (4): Linear(in_features=2048, out_features=1024, bias=True)
#           (5): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm()
#   )
#   (attn_pool): Attention(
#     (norm): LayerNorm()
#     (q_norm): RMSNorm()
#     (k_norm): RMSNorm()
#     (attend): Softmax(dim=-1)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (to_q): Linear(in_features=1024, out_features=1024, bias=False)
#     (to_kv): Linear(in_features=1024, out_features=2048, bias=False)
#     (to_out): Sequential(
#       (0): Linear(in_features=1024, out_features=1024, bias=False)
#       (1): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (to_latent): Identity()
#   (mlp_head): Sequential(
#     (0): LayerNorm()
#     (1): Linear(in_features=1024, out_features=30, bias=False)
#   )
# )

# %% [markdown]
# Kode Zufar

# %% [markdown]
# Kode Zufar + GPT tambahin akurasi doang

# %%
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(v.parameters(), lr=0.001, momentum=0.9)

# Inisialisasi list untuk menyimpan akurasi dan loss
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
test_accuracy = 0  # Akurasi pengujian hanya dihitung sekali di akhir

num_epochs = 100
for epoch in range(num_epochs):  # loop over the dataset multiple times
    correct = 0
    total = 0
    running_loss = 0.0  # Untuk menghitung training loss per epoch
    
    # Loop untuk setiap batch dalam trainloader
    for i, data in tqdm(enumerate(trainloader, 0), desc=f'Epoch {epoch + 1}/{num_epochs}'):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = v(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Menghitung jumlah prediksi yang benar
        _, predicted = torch.max(outputs.data, 1)  # Ambil kelas dengan probabilitas tertinggi
        total += labels.size(0)  # Menambah jumlah data yang telah diproses
        correct += (predicted == labels).sum().item()  # Hitung prediksi yang benar

        # Menghitung training loss
        running_loss += loss.item()

    # Akurasi dan loss per epoch pada data pelatihan
    accuracy = 100 * correct / total  # Akurasi dalam persentase
    epoch_loss = running_loss / len(trainloader)  # Rata-rata loss per epoch
    train_accuracies.append(accuracy)
    train_losses.append(epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Accuracy: {accuracy:.2f}%, Training Loss: {epoch_loss:.4f}')

    # Evaluasi pada data validasi
    v.eval()  # Set v ke mode evaluasi
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0  # Untuk menghitung validation loss per epoch
    with torch.no_grad():  # Non-aktifkan perhitungan gradien
        for data in valloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = v(inputs)
            loss = criterion(outputs, labels)
            val_running_loss += loss.item()  # Menghitung validation loss
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_accuracy = 100 * val_correct / val_total
    val_epoch_loss = val_running_loss / len(valloader)  # Rata-rata validation loss per epoch
    val_accuracies.append(val_accuracy)
    val_losses.append(val_epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Validation Accuracy: {val_accuracy:.2f}%, Validation Loss: {val_epoch_loss:.4f}')

    v.train()  # Kembalikan v ke mode pelatihan

print('Finished Training')

# Evaluasi pada data uji setelah pelatihan selesai
v.eval()  # Set v ke mode evaluasi
test_correct = 0
test_total = 0
with torch.no_grad():  # Non-aktifkan perhitungan gradien
    for data in testloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = v(inputs)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total
print(f'Test Accuracy: {test_accuracy:.2f}%')

# Plot grafik perbandingan akurasi dan loss
plt.figure(figsize=(12, 5))

# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy', marker='o')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy', marker='o')
# plt.axhline(y=test_accuracy, color='r', linestyle='--', label=f'Test Accuracy: {test_accuracy:.2f}%')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss', marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/100: 321it [00:07, 43.49it/s]
# Epoch [1/100], Training Accuracy: 12.77%, Training Loss: 3.4928
# Epoch [1/100], Validation Accuracy: 20.73%, Validation Loss: 2.7282
# Epoch 2/100: 321it [00:07, 44.00it/s]
# Epoch [2/100], Training Accuracy: 27.02%, Training Loss: 2.7558
# Epoch [2/100], Validation Accuracy: 28.00%, Validation Loss: 2.5401
# Epoch 3/100: 321it [00:07, 43.87it/s]
# Epoch [3/100], Training Accuracy: 37.77%, Training Loss: 2.1810
# Epoch [3/100], Validation Accuracy: 36.36%, Validation Loss: 2.2624
# Epoch 4/100: 321it [00:07, 44.84it/s]
# Epoch [4/100], Training Accuracy: 47.12%, Training Loss: 1.8113
# Epoch [4/100], Validation Accuracy: 36.73%, Validation Loss: 2.0833
# Epoch 5/100: 321it [00:07, 44.13it/s]
# Epoch [5/100], Training Accuracy: 50.31%, Training Loss: 1.7002
# Epoch [5/100], Validation Accuracy: 49.45%, Validation Loss: 1.9650
# Epoch 6/100: 321it [00:07, 44.42it/s]
# Epoch [6/100], Training Accuracy: 53.97%, Training Loss: 1.5565
# Epoch [6/100], Validation Accuracy: 58.18%, Validation Loss: 1.5470
# Epoch 7/100: 321it [00:07, 45.35it/s]
# Epoch [7/100], Training Accuracy: 52.73%, Training Loss: 1.6596
# Epoch [7/100], Validation Accuracy: 46.55%, Validation Loss: 2.1439
# Epoch 8/100: 321it [00:07, 45.45it/s]
# Epoch [8/100], Training Accuracy: 53.50%, Training Loss: 1.5781
# Epoch [8/100], Validation Accuracy: 55.64%, Validation Loss: 1.7082
# Epoch 9/100: 321it [00:07, 45.32it/s]
# Epoch [9/100], Training Accuracy: 62.31%, Training Loss: 1.2600
# Epoch [9/100], Validation Accuracy: 64.73%, Validation Loss: 1.0761
# Epoch 10/100: 321it [00:07, 45.53it/s]
# Epoch [10/100], Training Accuracy: 61.84%, Training Loss: 1.2086
# Epoch [10/100], Validation Accuracy: 58.18%, Validation Loss: 1.3550
# Epoch 11/100: 321it [00:06, 45.93it/s]
# Epoch [11/100], Training Accuracy: 65.65%, Training Loss: 1.1675
# Epoch [11/100], Validation Accuracy: 68.36%, Validation Loss: 0.9968
# Epoch 12/100: 321it [00:07, 44.49it/s]
# Epoch [12/100], Training Accuracy: 69.94%, Training Loss: 1.0034
# Epoch [12/100], Validation Accuracy: 60.36%, Validation Loss: 1.4612
# Epoch 13/100: 321it [00:07, 43.85it/s]
# Epoch [13/100], Training Accuracy: 68.93%, Training Loss: 1.0190
# Epoch [13/100], Validation Accuracy: 58.55%, Validation Loss: 1.4881
# Epoch 14/100: 321it [00:07, 44.77it/s]
# Epoch [14/100], Training Accuracy: 71.88%, Training Loss: 0.9798
# Epoch [14/100], Validation Accuracy: 57.82%, Validation Loss: 1.7284
# Epoch 15/100: 321it [00:07, 45.79it/s]
# Epoch [15/100], Training Accuracy: 69.08%, Training Loss: 0.9951
# Epoch [15/100], Validation Accuracy: 56.36%, Validation Loss: 1.6330
# Epoch 16/100: 321it [00:07, 44.76it/s]
# Epoch [16/100], Training Accuracy: 72.90%, Training Loss: 0.9247
# Epoch [16/100], Validation Accuracy: 68.73%, Validation Loss: 1.2260
# Epoch 17/100: 321it [00:07, 44.59it/s]
# Epoch [17/100], Training Accuracy: 75.31%, Training Loss: 0.8120
# Epoch [17/100], Validation Accuracy: 59.27%, Validation Loss: 1.5876
# Epoch 18/100: 321it [00:07, 45.63it/s]
# Epoch [18/100], Training Accuracy: 77.88%, Training Loss: 0.7287
# Epoch [18/100], Validation Accuracy: 72.36%, Validation Loss: 1.1497
# Epoch 19/100: 321it [00:07, 44.00it/s]
# Epoch [19/100], Training Accuracy: 76.79%, Training Loss: 0.7533
# Epoch [19/100], Validation Accuracy: 69.09%, Validation Loss: 1.1805
# Epoch 20/100: 321it [00:07, 43.86it/s]
# Epoch [20/100], Training Accuracy: 77.18%, Training Loss: 0.6851
# Epoch [20/100], Validation Accuracy: 65.09%, Validation Loss: 1.3164
# Epoch 21/100: 321it [00:07, 43.48it/s]
# Epoch [21/100], Training Accuracy: 76.09%, Training Loss: 0.7590
# Epoch [21/100], Validation Accuracy: 65.09%, Validation Loss: 1.4688
# Epoch 22/100: 321it [00:07, 45.09it/s]
# Epoch [22/100], Training Accuracy: 75.55%, Training Loss: 0.7390
# Epoch [22/100], Validation Accuracy: 68.36%, Validation Loss: 1.0857
# Epoch 23/100: 321it [00:07, 44.82it/s]
# Epoch [23/100], Training Accuracy: 79.36%, Training Loss: 0.6540
# Epoch [23/100], Validation Accuracy: 70.55%, Validation Loss: 1.0613
# Epoch 24/100: 321it [00:07, 45.44it/s]
# Epoch [24/100], Training Accuracy: 82.55%, Training Loss: 0.5406
# Epoch [24/100], Validation Accuracy: 74.91%, Validation Loss: 0.8839
# Epoch 25/100: 321it [00:07, 44.21it/s]
# Epoch [25/100], Training Accuracy: 85.75%, Training Loss: 0.4406
# Epoch [25/100], Validation Accuracy: 75.27%, Validation Loss: 0.8978
# Epoch 26/100: 321it [00:07, 44.42it/s]
# Epoch [26/100], Training Accuracy: 79.44%, Training Loss: 0.6230
# Epoch [26/100], Validation Accuracy: 65.82%, Validation Loss: 1.1165
# Epoch 27/100: 321it [00:07, 45.08it/s]
# Epoch [27/100], Training Accuracy: 84.74%, Training Loss: 0.4592
# Epoch [27/100], Validation Accuracy: 72.73%, Validation Loss: 1.0020
# Epoch 28/100: 321it [00:07, 45.14it/s]
# Epoch [28/100], Training Accuracy: 86.53%, Training Loss: 0.3978
# Epoch [28/100], Validation Accuracy: 72.36%, Validation Loss: 0.9983
# Epoch 29/100: 321it [00:07, 45.00it/s]
# Epoch [29/100], Training Accuracy: 89.02%, Training Loss: 0.3413
# Epoch [29/100], Validation Accuracy: 71.27%, Validation Loss: 1.0866
# Epoch 30/100: 321it [00:07, 45.71it/s]
# Epoch [30/100], Training Accuracy: 87.54%, Training Loss: 0.4012
# Epoch [30/100], Validation Accuracy: 75.64%, Validation Loss: 0.8618
# Epoch 31/100: 321it [00:07, 44.98it/s]
# Epoch [31/100], Training Accuracy: 85.44%, Training Loss: 0.4478
# Epoch [31/100], Validation Accuracy: 71.27%, Validation Loss: 1.0361
# Epoch 32/100: 321it [00:07, 44.10it/s]
# Epoch [32/100], Training Accuracy: 86.45%, Training Loss: 0.4054
# Epoch [32/100], Validation Accuracy: 72.00%, Validation Loss: 1.2125
# Epoch 33/100: 321it [00:07, 45.14it/s]
# Epoch [33/100], Training Accuracy: 83.57%, Training Loss: 0.4849
# Epoch [33/100], Validation Accuracy: 74.18%, Validation Loss: 0.9043
# Epoch 34/100: 321it [00:07, 45.35it/s]
# Epoch [34/100], Training Accuracy: 86.99%, Training Loss: 0.4016
# Epoch [34/100], Validation Accuracy: 77.82%, Validation Loss: 0.8430
# Epoch 35/100: 321it [00:07, 43.95it/s]
# Epoch [35/100], Training Accuracy: 90.42%, Training Loss: 0.2872
# Epoch [35/100], Validation Accuracy: 76.73%, Validation Loss: 0.9423
# Epoch 36/100: 321it [00:07, 44.83it/s]
# Epoch [36/100], Training Accuracy: 83.64%, Training Loss: 0.4784
# Epoch [36/100], Validation Accuracy: 76.00%, Validation Loss: 1.0009
# Epoch 37/100: 321it [00:07, 45.76it/s]
# Epoch [37/100], Training Accuracy: 87.23%, Training Loss: 0.3834
# Epoch [37/100], Validation Accuracy: 73.82%, Validation Loss: 0.9506
# Epoch 38/100: 321it [00:07, 44.13it/s]
# Epoch [38/100], Training Accuracy: 90.26%, Training Loss: 0.2935
# Epoch [38/100], Validation Accuracy: 74.55%, Validation Loss: 1.0081
# Epoch 39/100: 321it [00:07, 43.00it/s]
# Epoch [39/100], Training Accuracy: 89.80%, Training Loss: 0.2925
# Epoch [39/100], Validation Accuracy: 73.09%, Validation Loss: 0.9564
# Epoch 40/100: 321it [00:07, 43.28it/s]
# Epoch [40/100], Training Accuracy: 91.20%, Training Loss: 0.2765
# Epoch [40/100], Validation Accuracy: 75.27%, Validation Loss: 1.0063
# Epoch 41/100: 321it [00:07, 43.55it/s]
# Epoch [41/100], Training Accuracy: 94.39%, Training Loss: 0.1808
# Epoch [41/100], Validation Accuracy: 75.27%, Validation Loss: 1.1034
# Epoch 42/100: 321it [00:07, 43.95it/s]
# Epoch [42/100], Training Accuracy: 89.56%, Training Loss: 0.2980
# Epoch [42/100], Validation Accuracy: 74.18%, Validation Loss: 1.0395
# Epoch 43/100: 321it [00:07, 44.87it/s]
# Epoch [43/100], Training Accuracy: 90.73%, Training Loss: 0.2933
# Epoch [43/100], Validation Accuracy: 71.27%, Validation Loss: 1.1233
# Epoch 44/100: 321it [00:07, 43.79it/s]
# Epoch [44/100], Training Accuracy: 91.82%, Training Loss: 0.2477
# Epoch [44/100], Validation Accuracy: 77.82%, Validation Loss: 0.9071
# Epoch 45/100: 321it [00:07, 44.22it/s]
# Epoch [45/100], Training Accuracy: 91.51%, Training Loss: 0.2699
# Epoch [45/100], Validation Accuracy: 76.73%, Validation Loss: 1.0407
# Epoch 46/100: 321it [00:07, 43.37it/s]
# Epoch [46/100], Training Accuracy: 89.33%, Training Loss: 0.3302
# Epoch [46/100], Validation Accuracy: 72.36%, Validation Loss: 1.3575
# Epoch 47/100: 321it [00:06, 45.88it/s]
# Epoch [47/100], Training Accuracy: 91.12%, Training Loss: 0.2656
# Epoch [47/100], Validation Accuracy: 72.73%, Validation Loss: 0.8971
# Epoch 48/100: 321it [00:07, 45.36it/s]
# Epoch [48/100], Training Accuracy: 91.67%, Training Loss: 0.2470
# Epoch [48/100], Validation Accuracy: 75.27%, Validation Loss: 0.9331
# Epoch 49/100: 321it [00:07, 45.13it/s]
# Epoch [49/100], Training Accuracy: 92.83%, Training Loss: 0.1830
# Epoch [49/100], Validation Accuracy: 76.00%, Validation Loss: 0.9439
# Epoch 50/100: 321it [00:07, 45.36it/s]
# Epoch [50/100], Training Accuracy: 93.22%, Training Loss: 0.1975
# Epoch [50/100], Validation Accuracy: 77.82%, Validation Loss: 0.8032
# Epoch 51/100: 321it [00:07, 45.29it/s]
# Epoch [51/100], Training Accuracy: 95.87%, Training Loss: 0.1472
# Epoch [51/100], Validation Accuracy: 75.64%, Validation Loss: 0.9673
# Epoch 52/100: 321it [00:07, 43.11it/s]
# Epoch [52/100], Training Accuracy: 96.65%, Training Loss: 0.1058
# Epoch [52/100], Validation Accuracy: 78.55%, Validation Loss: 0.8252
# Epoch 53/100: 321it [00:07, 44.50it/s]
# Epoch [53/100], Training Accuracy: 95.56%, Training Loss: 0.1422
# Epoch [53/100], Validation Accuracy: 74.91%, Validation Loss: 1.0413
# Epoch 54/100: 321it [00:07, 44.16it/s]
# Epoch [54/100], Training Accuracy: 94.78%, Training Loss: 0.1526
# Epoch [54/100], Validation Accuracy: 75.64%, Validation Loss: 1.1090
# Epoch 55/100: 321it [00:07, 44.13it/s]
# Epoch [55/100], Training Accuracy: 95.02%, Training Loss: 0.1463
# Epoch [55/100], Validation Accuracy: 73.09%, Validation Loss: 1.3573
# Epoch 56/100: 321it [00:07, 43.86it/s]
# Epoch [56/100], Training Accuracy: 94.55%, Training Loss: 0.1577
# Epoch [56/100], Validation Accuracy: 73.09%, Validation Loss: 1.0625
# Epoch 57/100: 321it [00:07, 44.55it/s]
# Epoch [57/100], Training Accuracy: 94.94%, Training Loss: 0.1607
# Epoch [57/100], Validation Accuracy: 74.91%, Validation Loss: 1.0246
# Epoch 58/100: 321it [00:07, 44.29it/s]
# Epoch [58/100], Training Accuracy: 94.08%, Training Loss: 0.1901
# Epoch [58/100], Validation Accuracy: 76.00%, Validation Loss: 0.9326
# Epoch 59/100: 321it [00:07, 43.51it/s]
# Epoch [59/100], Training Accuracy: 93.77%, Training Loss: 0.1856
# Epoch [59/100], Validation Accuracy: 74.55%, Validation Loss: 1.1954
# Epoch 60/100: 321it [00:07, 43.09it/s]
# Epoch [60/100], Training Accuracy: 90.58%, Training Loss: 0.2910
# Epoch [60/100], Validation Accuracy: 73.09%, Validation Loss: 1.1363
# Epoch 61/100: 321it [00:07, 44.41it/s]
# Epoch [61/100], Training Accuracy: 90.03%, Training Loss: 0.2766
# Epoch [61/100], Validation Accuracy: 70.91%, Validation Loss: 1.3828
# Epoch 62/100: 321it [00:07, 43.96it/s]
# Epoch [62/100], Training Accuracy: 91.36%, Training Loss: 0.2607
# Epoch [62/100], Validation Accuracy: 76.36%, Validation Loss: 1.1062
# Epoch 63/100: 321it [00:07, 44.39it/s]
# Epoch [63/100], Training Accuracy: 92.06%, Training Loss: 0.2359
# Epoch [63/100], Validation Accuracy: 75.27%, Validation Loss: 1.0823
# Epoch 64/100: 321it [00:07, 44.92it/s]
# Epoch [64/100], Training Accuracy: 93.22%, Training Loss: 0.2071
# Epoch [64/100], Validation Accuracy: 74.55%, Validation Loss: 1.0790
# Epoch 65/100: 321it [00:07, 43.24it/s]
# Epoch [65/100], Training Accuracy: 92.91%, Training Loss: 0.2010
# Epoch [65/100], Validation Accuracy: 76.00%, Validation Loss: 1.0250
# Epoch 66/100: 321it [00:07, 44.43it/s]
# Epoch [66/100], Training Accuracy: 92.21%, Training Loss: 0.2217
# Epoch [66/100], Validation Accuracy: 74.18%, Validation Loss: 1.1835
# Epoch 67/100: 321it [00:07, 44.80it/s]
# Epoch [67/100], Training Accuracy: 93.30%, Training Loss: 0.2006
# Epoch [67/100], Validation Accuracy: 70.18%, Validation Loss: 1.1692
# Epoch 68/100: 321it [00:07, 44.85it/s]
# Epoch [68/100], Training Accuracy: 89.88%, Training Loss: 0.3068
# Epoch [68/100], Validation Accuracy: 73.09%, Validation Loss: 1.0633
# Epoch 69/100: 321it [00:07, 44.19it/s]
# Epoch [69/100], Training Accuracy: 92.52%, Training Loss: 0.2358
# Epoch [69/100], Validation Accuracy: 72.73%, Validation Loss: 1.0527
# Epoch 70/100: 321it [00:07, 45.48it/s]
# Epoch [70/100], Training Accuracy: 92.45%, Training Loss: 0.2094
# Epoch [70/100], Validation Accuracy: 76.73%, Validation Loss: 0.8859
# Epoch 71/100: 321it [00:07, 45.36it/s]
# Epoch [71/100], Training Accuracy: 95.09%, Training Loss: 0.1299
# Epoch [71/100], Validation Accuracy: 75.27%, Validation Loss: 1.0224
# Epoch 72/100: 321it [00:07, 44.22it/s]
# Epoch [72/100], Training Accuracy: 93.93%, Training Loss: 0.1828
# Epoch [72/100], Validation Accuracy: 75.64%, Validation Loss: 0.9819
# Epoch 73/100: 321it [00:07, 44.13it/s]
# Epoch [73/100], Training Accuracy: 95.87%, Training Loss: 0.1181
# Epoch [73/100], Validation Accuracy: 72.00%, Validation Loss: 1.2188
# Epoch 74/100: 321it [00:07, 44.66it/s]
# Epoch [74/100], Training Accuracy: 94.63%, Training Loss: 0.1657
# Epoch [74/100], Validation Accuracy: 73.09%, Validation Loss: 1.1574
# Epoch 75/100: 321it [00:07, 44.74it/s]
# Epoch [75/100], Training Accuracy: 92.13%, Training Loss: 0.2461
# Epoch [75/100], Validation Accuracy: 69.09%, Validation Loss: 1.3413
# Epoch 76/100: 321it [00:07, 43.42it/s]
# Epoch [76/100], Training Accuracy: 92.83%, Training Loss: 0.2073
# Epoch [76/100], Validation Accuracy: 77.09%, Validation Loss: 1.0608
# Epoch 77/100: 321it [00:07, 45.65it/s]
# Epoch [77/100], Training Accuracy: 93.69%, Training Loss: 0.1861
# Epoch [77/100], Validation Accuracy: 74.55%, Validation Loss: 1.2125
# Epoch 78/100: 321it [00:07, 43.34it/s]
# Epoch [78/100], Training Accuracy: 94.00%, Training Loss: 0.1892
# Epoch [78/100], Validation Accuracy: 74.18%, Validation Loss: 1.0401
# Epoch 79/100: 321it [00:07, 44.39it/s]
# Epoch [79/100], Training Accuracy: 88.94%, Training Loss: 0.3502
# Epoch [79/100], Validation Accuracy: 73.09%, Validation Loss: 1.2774
# Epoch 80/100: 321it [00:07, 43.21it/s]
# Epoch [80/100], Training Accuracy: 91.90%, Training Loss: 0.2466
# Epoch [80/100], Validation Accuracy: 75.27%, Validation Loss: 0.9827
# Epoch 81/100: 321it [00:07, 43.98it/s]
# Epoch [81/100], Training Accuracy: 93.77%, Training Loss: 0.1810
# Epoch [81/100], Validation Accuracy: 74.18%, Validation Loss: 1.0822
# Epoch 82/100: 321it [00:07, 44.50it/s]
# Epoch [82/100], Training Accuracy: 94.16%, Training Loss: 0.1784
# Epoch [82/100], Validation Accuracy: 75.64%, Validation Loss: 0.9428
# Epoch 83/100: 321it [00:07, 44.36it/s]
# Epoch [83/100], Training Accuracy: 90.50%, Training Loss: 0.2880
# Epoch [83/100], Validation Accuracy: 74.55%, Validation Loss: 1.1112
# Epoch 84/100: 321it [00:07, 44.34it/s]
# Epoch [84/100], Training Accuracy: 90.97%, Training Loss: 0.2442
# Epoch [84/100], Validation Accuracy: 75.27%, Validation Loss: 1.1034
# Epoch 85/100: 321it [00:07, 44.55it/s]
# Epoch [85/100], Training Accuracy: 88.86%, Training Loss: 0.3536
# Epoch [85/100], Validation Accuracy: 78.18%, Validation Loss: 0.9335
# Epoch 86/100: 321it [00:07, 43.98it/s]
# Epoch [86/100], Training Accuracy: 91.28%, Training Loss: 0.2623
# Epoch [86/100], Validation Accuracy: 76.00%, Validation Loss: 0.9442
# Epoch 87/100: 321it [00:07, 45.25it/s]
# Epoch [87/100], Training Accuracy: 94.47%, Training Loss: 0.1698
# Epoch [87/100], Validation Accuracy: 76.36%, Validation Loss: 0.9369
# Epoch 88/100: 321it [00:07, 45.50it/s]
# Epoch [88/100], Training Accuracy: 94.16%, Training Loss: 0.1653
# Epoch [88/100], Validation Accuracy: 73.45%, Validation Loss: 1.2046
# Epoch 89/100: 321it [00:07, 44.18it/s]
# Epoch [89/100], Training Accuracy: 92.52%, Training Loss: 0.1984
# Epoch [89/100], Validation Accuracy: 78.55%, Validation Loss: 1.0308
# Epoch 90/100: 321it [00:07, 45.69it/s]
# Epoch [90/100], Training Accuracy: 93.46%, Training Loss: 0.2113
# Epoch [90/100], Validation Accuracy: 72.00%, Validation Loss: 1.1410
# Epoch 91/100: 321it [00:07, 43.58it/s]
# Epoch [91/100], Training Accuracy: 94.63%, Training Loss: 0.1814
# Epoch [91/100], Validation Accuracy: 74.18%, Validation Loss: 1.0778
# Epoch 92/100: 321it [00:06, 46.13it/s]
# Epoch [92/100], Training Accuracy: 95.64%, Training Loss: 0.1252
# Epoch [92/100], Validation Accuracy: 74.91%, Validation Loss: 1.1399
# Epoch 93/100: 321it [00:07, 44.53it/s]
# Epoch [93/100], Training Accuracy: 94.86%, Training Loss: 0.1409
# Epoch [93/100], Validation Accuracy: 76.00%, Validation Loss: 1.1495
# Epoch 94/100: 321it [00:07, 44.36it/s]
# Epoch [94/100], Training Accuracy: 90.11%, Training Loss: 0.2794
# Epoch [94/100], Validation Accuracy: 72.73%, Validation Loss: 1.1938
# Epoch 95/100: 321it [00:07, 44.43it/s]
# Epoch [95/100], Training Accuracy: 91.36%, Training Loss: 0.2715
# Epoch [95/100], Validation Accuracy: 70.91%, Validation Loss: 1.1109
# Epoch 96/100: 321it [00:07, 44.93it/s]
# Epoch [96/100], Training Accuracy: 89.88%, Training Loss: 0.3145
# Epoch [96/100], Validation Accuracy: 79.27%, Validation Loss: 0.8678
# Epoch 97/100: 321it [00:07, 44.17it/s]
# Epoch [97/100], Training Accuracy: 90.58%, Training Loss: 0.2674
# Epoch [97/100], Validation Accuracy: 76.36%, Validation Loss: 0.9984
# Epoch 98/100: 321it [00:07, 43.91it/s]
# Epoch [98/100], Training Accuracy: 94.16%, Training Loss: 0.1939
# Epoch [98/100], Validation Accuracy: 74.91%, Validation Loss: 0.9872
# Epoch 99/100: 321it [00:07, 44.75it/s]
# Epoch [99/100], Training Accuracy: 95.25%, Training Loss: 0.1484
# Epoch [99/100], Validation Accuracy: 80.73%, Validation Loss: 0.8885
# Epoch 100/100: 321it [00:07, 43.10it/s]
# Epoch [100/100], Training Accuracy: 95.02%, Training Loss: 0.1606
# Epoch [100/100], Validation Accuracy: 74.91%, Validation Loss: 1.0134
# Finished Training
# Test Accuracy: 77.54%

# %%
import pandas as pd

# Create a DataFrame with the training and validation results
results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs + 1)),
    'Training Accuracy': train_accuracies,
    'Validation Accuracy': val_accuracies,
    'Training Loss': train_losses,
    'Validation Loss': val_losses
})

# Save the DataFrame to a CSV file
results_csv_path = 'training_results_NaViT.csv'
results_df.to_csv(results_csv_path, index=False)
print(f"Training results saved to {results_csv_path}")
# Out:
# Training results saved to training_results_NaViT.csv

# %%
PATH = './model_NaViT.pth'
torch.save(v.state_dict(), PATH)
print(f"Model saved to {PATH}")
# Out:
# Model saved to ./model_NaViT.pth

# %%
# prepare to count predictions for each class
classes = (['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)'])
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = v(images.to(device))
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
    # print(classname,correct_count)
# Out:
# Accuracy for class: Alpinia Galanga (Rasna) is 33.3 %
# Accuracy for class: Amaranthus Viridis (Arive-Dantu) is 70.8 %
# Accuracy for class: Artocarpus Heterophyllus (Jackfruit) is 100.0 %
# Accuracy for class: Azadirachta Indica (Neem) is 57.1 %
# Accuracy for class: Basella Alba (Basale) is 70.0 %
# Accuracy for class: Brassica Juncea (Indian Mustard) is 100.0 %
# Accuracy for class: Carissa Carandas (Karanda) is 100.0 %
# Accuracy for class: Citrus Limon (Lemon) is 100.0 %
# Accuracy for class: Ficus Auriculata (Roxburgh fig) is 28.6 %
# Accuracy for class: Ficus Religiosa (Peepal Tree) is 100.0 %
# Accuracy for class: Hibiscus Rosa-sinensis is 61.5 %
# Accuracy for class: Jasminum (Jasmine) is 66.7 %
# Accuracy for class: Mangifera Indica (Mango) is 57.1 %
# Accuracy for class: Mentha (Mint) is 100.0 %
# Accuracy for class: Moringa Oleifera (Drumstick) is 100.0 %
# Accuracy for class: Muntingia Calabura (Jamaica Cherry-Gasagase) is 87.5 %
# Accuracy for class: Murraya Koenigii (Curry) is 60.0 %
# Accuracy for class: Nerium Oleander (Oleander) is 72.7 %
# Accuracy for class: Nyctanthes Arbor-tristis (Parijata) is 66.7 %
# Accuracy for class: Ocimum Tenuiflorum (Tulsi) is 55.6 %
# Accuracy for class: Piper Betle (Betel) is 53.8 %
# Accuracy for class: Plectranthus Amboinicus (Mexican Mint) is 100.0 %
# Accuracy for class: Pongamia Pinnata (Indian Beech) is 100.0 %
# Accuracy for class: Psidium Guajava (Guava) is 100.0 %
# Accuracy for class: Punica Granatum (Pomegranate) is 66.7 %
# Accuracy for class: Santalum Album (Sandalwood) is 100.0 %
# Accuracy for class: Syzygium Cumini (Jamun) is 66.7 %
# Accuracy for class: Syzygium Jambos (Rose Apple) is 100.0 %
# Accuracy for class: Tabernaemontana Divaricata (Crape Jasmine) is 75.0 %
# Accuracy for class: Trigonella Foenum-graecum (Fenugreek) is 71.4 %

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Mengumpulkan semua label sebenarnya dan prediksi
all_labels = []
all_predictions = []

with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = v(images.to(device))
        _, predictions = torch.max(outputs, 1)
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predictions.cpu().numpy())

# Membuat confusion matrix
cm = confusion_matrix(all_labels, all_predictions)

# Menampilkan confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# Agar model terbaik yang disave

# %%
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# Inisialisasi variabel untuk menyimpan model terbaik
best_val_accuracy = 0.0
best_model_state = None

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(v.parameters(), lr=0.001, momentum=0.9)

# Inisialisasi list untuk menyimpan akurasi dan loss
train_accuracies = []
val_accuracies = []
train_losses = []
val_losses = []
test_accuracy = 0  # Akurasi pengujian hanya dihitung sekali di akhir

num_epochs = 100
for epoch in range(num_epochs):  # loop over the dataset multiple times
    correct = 0
    total = 0
    running_loss = 0.0  # Untuk menghitung training loss per epoch
    
    # Loop untuk setiap batch dalam trainloader
    for i, data in tqdm(enumerate(trainloader, 0), desc=f'Epoch {epoch + 1}/{num_epochs}'):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = v(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # Menghitung jumlah prediksi yang benar
        _, predicted = torch.max(outputs.data, 1)  # Ambil kelas dengan probabilitas tertinggi
        total += labels.size(0)  # Menambah jumlah data yang telah diproses
        correct += (predicted == labels).sum().item()  # Hitung prediksi yang benar

        # Menghitung training loss
        running_loss += loss.item()

    # Akurasi dan loss per epoch pada data pelatihan
    accuracy = 100 * correct / total  # Akurasi dalam persentase
    epoch_loss = running_loss / len(trainloader)  # Rata-rata loss per epoch
    train_accuracies.append(accuracy)
    train_losses.append(epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Accuracy: {accuracy:.2f}%, Training Loss: {epoch_loss:.4f}')

    # Evaluasi pada data validasi
    v.eval()  # Set v ke mode evaluasi
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0  # Untuk menghitung validation loss per epoch
    with torch.no_grad():  # Non-aktifkan perhitungan gradien
        for data in valloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = v(inputs)
            loss = criterion(outputs, labels)
            val_running_loss += loss.item()  # Menghitung validation loss
            _, predicted = torch.max(outputs.data, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_accuracy = 100 * val_correct / val_total
    val_epoch_loss = val_running_loss / len(valloader)  # Rata-rata validation loss per epoch
    val_accuracies.append(val_accuracy)
    val_losses.append(val_epoch_loss)
    print(f'Epoch [{epoch + 1}/{num_epochs}], Validation Accuracy: {val_accuracy:.2f}%, Validation Loss: {val_epoch_loss:.4f}')

    # Cek apakah model ini yang terbaik berdasarkan akurasi validasi
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_model_state = v.state_dict().copy()  # Simpan state dict model
        print(f'New best model found at epoch {epoch+1} with validation accuracy: {val_accuracy:.2f}%')
        # Anda juga bisa menyimpan model ke file di sini:
        # torch.save(v.state_dict(), 'best_model.pth')

    v.train()  # Kembalikan v ke mode pelatihan

print('Finished Training')

# Load model terbaik sebelum evaluasi akhir
if best_model_state is not None:
    v.load_state_dict(best_model_state)
    print(f'Loaded best model with validation accuracy: {best_val_accuracy:.2f}%')

# Evaluasi pada data uji setelah pelatihan selesai
v.eval()  # Set v ke mode evaluasi
test_correct = 0
test_total = 0
with torch.no_grad():  # Non-aktifkan perhitungan gradien
    for data in testloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = v(inputs)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total
print(f'Test Accuracy: {test_accuracy:.2f}%')

# Simpan model terbaik ke file (opsional)
torch.save({
    'model_state_dict': best_model_state,
    'best_val_accuracy': best_val_accuracy,
    'test_accuracy': test_accuracy,
}, 'best_model.pth')

# Plot grafik perbandingan akurasi dan loss
plt.figure(figsize=(12, 5))

# Plot Akurasi
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Training Accuracy', marker='o')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy', marker='o')
plt.axhline(y=test_accuracy, color='r', linestyle='--', label=f'Test Accuracy: {test_accuracy:.2f}%')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_losses, label='Training Loss', marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
